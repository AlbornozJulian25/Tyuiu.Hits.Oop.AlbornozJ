// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
public class Animal
{
    private string name;
    public string Name
    {
        get {return name;}
        set {name = value;}
    }

    private int age;
    public int Age 
    {
        get {return age;}
        set
        {
            if (value >= 0)
            age = value;

            else

            throw new ArgumentOutOfRangeException("The age can not be negative");
        }
    }

    private static int totalAnimal;
    public static int TotalAnimal
    {
        get {return totalAnimal;}
        private set { totalAnimal = value;}
    }

    public Animal()
    {
        totalAnimal++;
    }

    public Animal(string name, int age)
    {
        Name = name;
        Age = age;
        totalAnimal++;
    }

    public virtual void MakeASound()
    {
        Console.WriteLine("The animal makes a sound");
    }

    public virtual void Eat()
    {
        Console.WriteLine("The animal eats");
    }

    public static void DisplayTotalAnimal()
    {
        Console.WriteLine("Total animal is " + Animal.TotalAnimal);
    }
}

public class Dog : Animal
{
    private string breed;
    public string Breed 
    {
        get {return breed;}
        set { breed = value;}
    }

    public Dog() : base()
    {}

    public Dog(string breed, string name, int age) : base(name, age)
    {
        Breed = breed;        
    }

    public override void MakeASound()
    {
        Console.WriteLine("The dog barks");
    }

    public override void Eat()
    {
        Console.WriteLine("The dog eats kibble");
    }

    public void Play()
    {
        Console.WriteLine("The dog plays with the ball");
    }            
}

public class Squirrel : Animal
{
    private string color;
    public string Color
    {
        get {return color;}
        set {color = value;}
    }

    public Squirrel() : base()
    {}

    public Squirrel(string color, string name, int age) : base(name, age)
    {
        Color = color;
    }

    public override void MakeASound()
    {
        Console.WriteLine("The squirrel chatters");
    }

    public override void Eat()
    {
        Console.WriteLine("The squirrel eats nuts");
    }

    public void Sleep()
    {
        Console.WriteLine("The squirrel sleeps in the tree");
    }
}

public class Condor : Animal
{
    private int speed;
    public int Speed
    {
        get {return speed;}
        set 
        {
            if (value>=0 && value<=120)
            speed = value;

            else

            throw new ArgumentOutOfRangeException("The condor speed at flying is between 0 and 120 km/h");
        }
    }

    public Condor() : base()
    {}

    public Condor(int speed, string name, int age) : base (name, age)
    {
        Speed = speed;
    }

    public override void MakeASound()
    {
        Console.WriteLine("The condor croaks");
    }

    public override void Eat()
    {
        Console.WriteLine("The condor eats carrion");
    }

    public void Soar()
    {
        Console.WriteLine("The condor soars in the sky");
    }
}

Animal myAnimal = new Animal();
Dog myDog = new Dog();
Squirrel mySquirrel = new Squirrel();
Condor myCondor = new Condor();

myAnimal.Name = "Armando";
myAnimal.Age = 30;
Console.WriteLine("My animal name: " + myAnimal.Name);
Console.WriteLine("My animal is " + myAnimal.Age + " years old");

myAnimal.MakeASound();
myAnimal.Eat();


myDog.Name = "Chinito";
myDog.Age = 25;
myDog.Breed = "Viringo";
Console.WriteLine("My dog name: " + myDog.Name);
Console.WriteLine(myDog.Name + " is " + myDog.Age + " years old");
Console.WriteLine(myDog.Name + "'s breed is " + myDog.Breed);

myDog.MakeASound();
myDog.Eat();
myDog.Play();


mySquirrel.Name = "Skwovet";
mySquirrel.Age = 10;
mySquirrel.Color = "grey";
Console.WriteLine("The squirrel name: " + mySquirrel.Name);
Console.WriteLine(mySquirrel.Name + " is " + mySquirrel.Age + " years old");
Console.WriteLine(mySquirrel.Name + " is " +  mySquirrel.Color);

mySquirrel.MakeASound();
mySquirrel.Eat();
mySquirrel.Sleep();


myCondor.Name = "José";
myCondor.Age = 19;
myCondor.Speed = 15;
Console.WriteLine("My condor name: " + myCondor.Name);
Console.WriteLine(myCondor.Name + " is " + myCondor.Age + " years old");
Console.WriteLine(myCondor.Name + "'s speed is " + myCondor.Speed + " km/h");

myCondor.MakeASound();
myCondor.Eat();
myCondor.Soar();

Animal.DisplayTotalAnimal();
// Out:
// My animal name: Armando
// My animal is 30 years old
// The animal makes a sound
// The animal eats
// My dog name: Chinito
// Chinito is 25 years old
// Chinito's breed is Viringo
// The dog barks
// The dog eats kibble
// The dog plays with the ball
// The squirrel name: Skwovet
// Skwovet is 10 years old
// Skwovet is grey
// The squirrel chatters
// The squirrel eats nuts
// The squirrel sleeps in the tree
// My condor name: José
// José is 19 years old
// José's speed is 15 km/h
// The condor croaks
// The condor eats carrion
// The condor soars in the sky
// Total animal is 4
